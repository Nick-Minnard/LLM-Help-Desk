# %% [markdown]
# ## **Context**
#
#
#
#
# We are going to use a large language model to automate the classification and processing of user help desk support tickets.  The ultimate goal would be to predict ticket categories, assign priority, suggest estimated resolution time, generate a response based on sentiment analysis from the LLM, and create output that is stored in a dataframe. The input file is Support_ticket_text_data.xls.
#
# The dateframe should have 7 columns:
#
# Support ticket ID (from input file), support ticket text (from input file), category, tags, priority, estimated resolution time, and a generated reply from the LLM.

# %% [markdown]
# ## **Project Objective**
#
# Develop a Generative AI application using a Large Language Model to **automate the classification and processing of support tickets.** The application will aim to predict ticket categories, assign priority, suggest estimated resolution times, generate responses based on sentiment analysis, and store the results in a structured DataFrame.

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.16.1-py3-none-any.whl (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.9/266.9 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.16.1

# %%
import openai, json, pandas as pd, os

# %%
# Mount Google drive to access the dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Read a CSV file into a DataFrame and store it in the 'data' variable
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ARTI 330 Help Desk LLM/Support_ticket_text_data.csv')

# %%
df.shape
# Out:
# (27, 2)

# %%
df.head()
# Out:
#   support_tick_id                                support_ticket_text
# 0      ST2024-001    How do you find the mac address on my computer?
# 1      ST2024-002  I dropped my laptop in the parking lot and it ...
# 2      ST2024-003  The screen resolution on my computer monitor d...
# 3      ST2024-004  How do you get a virus off of my computer? I c...
# 4      ST2024-005  I can't get my computer to print to my printer...

# %%
# !openai --version
# Out:
# openai 1.16.1

# %%
# Loading my API Key from a google drive text file, not the most secure I know...
client = openai.OpenAI(api_key=open('/content/drive/MyDrive/Colab Notebooks/openai-api-key.txt', 'r').read())

# %%
# Uses a GPT API to generate specific JSON Output
def generate_response(ticket_text):
    sys_msg = f'''You are a helpful assistant designed to output JSON.

    "classification": A classification of the ticket as either a Technical Issue, a Hardware Issue, or a Data Recovery Issue
    "tags": Space-separated generalized tags that indicate the area of the problem more specifically
    "priority": A priority level for the support ticket
    "resolution time": An estimation of an approximate resolution time for the ticket
    "reply": A reply to the support ticket offering potential steps to solve the problem. Steps are formatted as one sentence'''

    # Generate response using GPT-3.5 Turbo
    response = client.chat.completions.create(
      model="gpt-3.5-turbo",
      response_format={ "type": "json_object" },
      messages=[
        {"role": "system", "content": sys_msg},
        {"role": "user", "content": f'Respond exactly with the specified JSON format for the ticket: {ticket_text}'}
      ]
    )

    return response.choices[0].message.content.strip()

# %%
# Generating responses for each column in the dataframe
df['gpt_response'] = df['support_ticket_text'].apply(lambda x: generate_response(x))

# %%
df.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2024-001    How do you find the mac address on my computer?
# 1      ST2024-002  I dropped my laptop in the parking lot and it ...
# 2      ST2024-003  The screen resolution on my computer monitor d...
# 3      ST2024-004  How do you get a virus off of my computer? I c...
# 4      ST2024-005  I can't get my computer to print to my printer...
#
#                                         gpt_response
# 0  {\n    "classification": "Technical Issue",\n ...
# 1  {\n    "classification": "Data Recovery Issue"...
# 2  {\n    "classification": "Technical Issue",\n ...
# 3  {\n    "classification": "Technical Issue",\n ...
# 4  {\n    "classification": "Hardware Issue",\n  ...

# %%
# Looking at one response in full
df['gpt_response'][0]
# Out:
# '{\n    "classification": "Technical Issue",\n    "tags": "Network Hardware",\n    "priority": "Medium",\n    "resolution time": "1-2 business days",\n    "reply": "To find the MAC address on your computer, you can open Command Prompt and type \'ipconfig /all\'. Look for the \'Physical Address\' under the network adapter you are interested in."\n}'

# %%
# Function that attempts to parse a json reponse
def extract_json_data(response):
  try:
    json_str = response[response.index('{'):response.index('}')+1]
  except:
    print('Brackets not detected in response.')
    return {}
  try:
    data_dict = json.loads(json_str)
    return data_dict
  except json.JSONDecodeError as e:
    print(f"Error parsing JSON: {e}")
    return {}

# %%
# Parsing the JSON responses for every column
df['parsed_response'] = df['gpt_response'].apply(lambda x: extract_json_data(x))

# %%
df.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2024-001    How do you find the mac address on my computer?
# 1      ST2024-002  I dropped my laptop in the parking lot and it ...
# 2      ST2024-003  The screen resolution on my computer monitor d...
# 3      ST2024-004  How do you get a virus off of my computer? I c...
# 4      ST2024-005  I can't get my computer to print to my printer...
#
#                                         gpt_response  \
# 0  {\n    "classification": "Technical Issue",\n ...
# 1  {\n    "classification": "Data Recovery Issue"...
# 2  {\n    "classification": "Technical Issue",\n ...
# 3  {\n    "classification": "Technical Issue",\n ...
# 4  {\n    "classification": "Hardware Issue",\n  ...
#
#                                      parsed_response
# 0  {'classification': 'Technical Issue', 'tags': ...
# 1  {'classification': 'Data Recovery Issue', 'tag...
# 2  {'classification': 'Technical Issue', 'tags': ...
# 3  {'classification': 'Technical Issue', 'tags': ...
# 4  {'classification': 'Hardware Issue', 'tags': '...

# %%
# A cleaned up version of the JSON response
df['parsed_response'][0]
# Out:
# {'classification': 'Technical Issue',
#  'tags': 'Network Hardware',
#  'priority': 'Medium',
#  'resolution time': '1-2 business days',
#  'reply': "To find the MAC address on your computer, you can open Command Prompt and type 'ipconfig /all'. Look for the 'Physical Address' under the network adapter you are interested in."}

# %% [markdown]
# ### **Creating a report**

# %%
# Extracting the five features and adding them to the dataframe
df = pd.concat([df, pd.json_normalize(df['parsed_response'])], axis=1)

# %%
df.head()
# Out:
#   support_tick_id                                support_ticket_text  \
# 0      ST2024-001    How do you find the mac address on my computer?
# 1      ST2024-002  I dropped my laptop in the parking lot and it ...
# 2      ST2024-003  The screen resolution on my computer monitor d...
# 3      ST2024-004  How do you get a virus off of my computer? I c...
# 4      ST2024-005  I can't get my computer to print to my printer...
#
#                                         gpt_response  \
# 0  {\n    "classification": "Technical Issue",\n ...
# 1  {\n    "classification": "Data Recovery Issue"...
# 2  {\n    "classification": "Technical Issue",\n ...
# 3  {\n    "classification": "Technical Issue",\n ...
# 4  {\n    "classification": "Hardware Issue",\n  ...
#
#                                      parsed_response       classification  \
# 0  {'classification': 'Technical Issue', 'tags': ...      Technical Issue
# 1  {'classification': 'Data Recovery Issue', 'tag...  Data Recovery Issue
# 2  {'classification': 'Technical Issue', 'tags': ...      Technical Issue
# 3  {'classification': 'Technical Issue', 'tags': ...      Technical Issue
# 4  {'classification': 'Hardware Issue', 'tags': '...       Hardware Issue
#
#                      tags priority    resolution time  \
# 0        Network Hardware   Medium  1-2 business days
# 1  Hardware Data-Recovery     High           2-3 days
# 2      Display Resolution   Medium  1-2 business days
# 3           Virus Removal     High    Within 24 hours
# 4          Printing Power   Medium           1-2 days
#
#                                                reply
# 0  To find the MAC address on your computer, you ...
# 1  It seems like your laptop may have suffered ha...
# 2  To increase the screen resolution on your comp...
# 3  To remove the virus from your computer, please...
# 4  Please double-check the connection between you...

# %%
# Dropping unecessary columns
df.drop(['gpt_response', 'parsed_response'], inplace=True, axis=1)

# %%
df.sample(df.shape[0])
# Out:
#    support_tick_id                                support_ticket_text  \
# 20      ST2024-021  My internet connection is frequently dropping,...
# 6       ST2024-007  Urgent help required! My laptop refuses to sta...
# 24      ST2024-025  I am experiencing a critical problem with my i...
# 7       ST2024-008  I've accidentally deleted essential work docum...
# 15      ST2024-016  I accidentally formatted my USB drive with cri...
# 0       ST2024-001    How do you find the mac address on my computer?
# 4       ST2024-005  I can't get my computer to print to my printer...
# 21      ST2024-022  Wi-Fi is inconsistent despite proximity to the...
# 25      ST2024-026  I hope this message finds you well. I am writi...
# 12      ST2023-013  I'm experiencing a recurring blue screen error...
# 3       ST2024-004  How do you get a virus off of my computer? I c...
# 17      ST2024-018  I accidentally spilled water on my laptop, and...
# 13      ST2024-014  My external hard drive isn't being recognized ...
# 18      ST2024-019  My USB flash drive is physically damaged, and ...
# 23      ST2024-024  My external hard drive isn't being recognized,...
# 19      ST2024-020  The touchpad on my laptop has stopped working,...
# 22      ST2024-023  I accidentally formatted my USB drive with cru...
# 10      ST2024-011  I'm locked out of my online banking account an...
# 2       ST2024-003  The screen resolution on my computer monitor d...
# 5       ST2024-006  My internet connection has significantly slowe...
# 16      ST2024-017  My computer's screen has gone black, and I can...
# 26      ST2024-026               Ayudame.  Mi computadora no trabajo.
# 8       ST2024-009  Despite being in close proximity to my Wi-Fi r...
# 14      ST2024-015  The graphics card in my gaming laptop seems to...
# 11      ST2024-012  My computer's performance is sluggish, severel...
# 1       ST2024-002  I dropped my laptop in the parking lot and it ...
# 9       ST2024-010  My smartphone battery is draining rapidly, eve...
#
#          classification                                       tags priority  \
# 20      Technical Issue                        Internet Connection     High
# 6        Hardware Issue          laptop start crucial-presentation   Urgent
# 24      Technical Issue                      Internet Connectivity     High
# 7   Data Recovery Issue                              data recovery     High
# 15  Data Recovery Issue                              Data Recovery     High
# 0       Technical Issue                           Network Hardware   Medium
# 4        Hardware Issue                             Printing Power   Medium
# 21      Technical Issue                  Wi-Fi Router Connectivity     High
# 25  Data Recovery Issue                Software Behavior Data Loss     High
# 12       Hardware Issue                                PC Hardware     High
# 3       Technical Issue                              Virus Removal     High
# 17       Hardware Issue                 Water Damage Data Recovery     High
# 13  Data Recovery Issue          external hard drive data recovery     High
# 18       Hardware Issue              USB flash drive data recovery     High
# 23  Data Recovery Issue          external hard drive data recovery     High
# 19       Hardware Issue                   laptop touchpad hardware     High
# 22  Data Recovery Issue                              Data Recovery     High
# 10      Technical Issue                       Login Password Reset     High
# 2       Technical Issue                         Display Resolution   Medium
# 5       Technical Issue  Internet Connectivity Slow Disconnections     High
# 16       Hardware Issue                               Screen Black     High
# 26      Technical Issue                  Computer Operating System     High
# 8       Technical Issue                      Wi-Fi Signal Weakness     High
# 14       Hardware Issue                graphics card gaming laptop     High
# 11      Technical Issue                   Performance Optimization     High
# 1   Data Recovery Issue                     Hardware Data-Recovery     High
# 9        Hardware Issue                smartphone battery draining   Medium
#
#       resolution time                                              reply
# 20     Within 4 hours  Please try restarting your router and modem to...
# 6     Within 24 hours  Please try performing a hard reset on your lap...
# 24    Within 24 hours  To address the slow internet speed and frequen...
# 7     Within 24 hours  We understand the urgency of your situation. T...
# 15           1-2 days  To recover files from a formatted USB drive, y...
# 0   1-2 business days  To find the MAC address on your computer, you ...
# 4            1-2 days  Please double-check the connection between you...
# 21          1-2 hours  Please try restarting your router and reconnec...
# 25  2-3 business days  Based on the description provided, it appears ...
# 12           1-2 days  To diagnose the blue screen error, start by ch...
# 3     Within 24 hours  To remove the virus from your computer, please...
# 17           1-2 days  To assess the damage and recover your data, pl...
# 13           1-2 days  Please try connecting the external hard drive ...
# 18  1-2 business days  We recommend contacting a professional data re...
# 23           1-2 days  Please try connecting the external hard drive ...
# 19  1-2 business days  Please try restarting your laptop and updating...
# 22           1-2 days  To recover the formatted data from your USB dr...
# 10             1 hour  Please attempt to reset your password using th...
# 2   1-2 business days  To increase the screen resolution on your comp...
# 5     Within 24 hours  Please try restarting your modem and router to...
# 16            2 hours  Please try restarting your computer and checki...
# 26           1-2 days  Please try restarting your computer and check ...
# 8            1-2 days  Please try relocating your router to a central...
# 14  2-3 business days  To diagnose the issue with your graphics card,...
# 11           1-2 days  To optimize your computer's performance, try c...
# 1            2-3 days  It seems like your laptop may have suffered ha...
# 9            1-2 days  To address the rapid battery drain issue, try ...

# %% [markdown]
# It feels a little like cheating to use a GPT model but it serves the same purpose. Moreover, even using to oldest and cheapest model available, GPT achieves more consistency than the Llama model did when I got it to work previsouly. The Llama model routinly failed to generate responses for 4 or 5 of the 27 support tickets, and the responses it did generate were of less quality.
#
# The model aside there isn't much more to this notebook. The extract_json_data function was tweaked to add additional error handling, but it doesn't appear necessary with GPT-3.5-Turbo.
#
# With some small changes, this code could be used to target certain tickets. My vision is that the system could tag tickets once their created so this script could be run automatically and generate responses for only tickets that still need them.

# %% [markdown]
# ---
